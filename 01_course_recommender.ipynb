# %%
#import libraries
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
#load datasets
df = pd.read_csv('coursera_courses.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5411 entries, 0 to 5410
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             5411 non-null   object
#  1   name            5411 non-null   object
#  2   category        5411 non-null   object
#  3   what_you_learn  3005 non-null   object
#  4   skills          5411 non-null   object
#  5   language        5411 non-null   object
#  6   instructors     5411 non-null   object
#  7   content         5411 non-null   object
# dtypes: object(8)
# memory usage: 338.3+ KB

# %%
df.head(3)
# Out:
#                                                  url  \
# 0   https://www.coursera.org/learn/-network-security
# 1  https://www.coursera.org/learn/-security-princ...
# 2  https://www.coursera.org/learn/21st-century-en...
#
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
#
#                            category  \
# 0            Information Technology
# 1            Information Technology
# 2  Physical Science And Engineering
#
#                                       what_you_learn  \
# 0                                                NaN
# 1                                                NaN
# 2  Understand the complexity of systems supplying...
#
#                                               skills language     instructors  \
# 0  Computer Networking, Network Planning And Desi...  English   ['~31081695']
# 1  Cyber Security Policies, Data Integrity, Cyber...  English   ['~31081695']
# 2  Electric Power Systems, Environmental Policy, ...  English  ['brad-hayes']
#
#                                              content
# 0  Welcome to course 4 of 5 of this Specializatio...
# 1  Welcome to course 1 of 5 of this Specializatio...
# 2  NOTE: “21 st Century Energy Transition – How d...

# %%
# Define columns to fill
cols = ['name', 'category', 'what_you_learn', 'skills', 'language', 'instructors', 'content']

# Fill missing values for selected columns
df[cols] = df[cols].fillna('')

# Drop rows where name is missing
df = df.dropna(subset=['name'])

df.head()
# Out:
#                                                  url  \
# 0   https://www.coursera.org/learn/-network-security
# 1  https://www.coursera.org/learn/-security-princ...
# 2  https://www.coursera.org/learn/21st-century-en...
# 3  https://www.coursera.org/learn/360-vr-video-pr...
# 4  https://www.coursera.org/learn/3d-anatomy-phys...
#
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
# 3                        VR and 360 Video Production
# 4        Foundations of Human Anatomy and Physiology
#
#                            category  \
# 0            Information Technology
# 1            Information Technology
# 2  Physical Science And Engineering
# 3               Arts And Humanities
# 4                            Health
#
#                                       what_you_learn  \
# 0
# 1
# 2  Understand the complexity of systems supplying...
# 3
# 4  Learners will understand how body structure su...
#
#                                               skills language  \
# 0  Computer Networking, Network Planning And Desi...  English
# 1  Cyber Security Policies, Data Integrity, Cyber...  English
# 2  Electric Power Systems, Environmental Policy, ...  English
# 3  Virtual Reality, Videography, Media Production...  English
# 4  Vital Signs, Basic Patient Care, Anatomy, Heal...  English
#
#                                          instructors  \
# 0                                      ['~31081695']
# 1                                      ['~31081695']
# 2                                     ['brad-hayes']
# 3                                     ['googlearvr']
# 4  ['~167016541', '~166856472', '~166856442', '~1...
#
#                                              content
# 0  Welcome to course 4 of 5 of this Specializatio...
# 1  Welcome to course 1 of 5 of this Specializatio...
# 2  NOTE: “21 st Century Energy Transition – How d...
# 3  Welcome to the Google AR & VR Virtual Reality ...
# 4  This course provides a foundational understand...

# %%
df['text'] = (
    df['name'] + ' ' +
    df['category'] + ' ' +
    df['skills'] + ' ' +
    df['what_you_learn'] + ' ' +
    df['content'] + ' ' +
    df['language'] + ' ' +
    df['instructors']
)

df[['name', 'text']].head()
# Out:
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
# 3                        VR and 360 Video Production
# 4        Foundations of Human Anatomy and Physiology
#
#                                                 text
# 0  Network Security Information Technology Comput...
# 1  Security Principles Information Technology Cyb...
# 2  21st Century Energy Transition: how do we make...
# 3  VR and 360 Video Production Arts And Humanitie...
# 4  Foundations of Human Anatomy and Physiology He...

# %%
df.head()
# Out:
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
# 3                        VR and 360 Video Production
# 4        Foundations of Human Anatomy and Physiology
#
#                            category  \
# 0            Information Technology
# 1            Information Technology
# 2  Physical Science And Engineering
# 3               Arts And Humanities
# 4                            Health
#
#                                       what_you_learn  \
# 0
# 1
# 2  Understand the complexity of systems supplying...
# 3
# 4  Learners will understand how body structure su...
#
#                                               skills language  \
# 0  Computer Networking, Network Planning And Desi...  English
# 1  Cyber Security Policies, Data Integrity, Cyber...  English
# 2  Electric Power Systems, Environmental Policy, ...  English
# 3  Virtual Reality, Videography, Media Production...  English
# 4  Vital Signs, Basic Patient Care, Anatomy, Heal...  English
#
#                                          instructors  \
# 0                                      ['~31081695']
# 1                                      ['~31081695']
# 2                                     ['brad-hayes']
# 3                                     ['googlearvr']
# 4  ['~167016541', '~166856472', '~166856442', '~1...
#
#                                              content  \
# 0  Welcome to course 4 of 5 of this Specializatio...
# 1  Welcome to course 1 of 5 of this Specializatio...
# 2  NOTE: “21 st Century Energy Transition – How d...
# 3  Welcome to the Google AR & VR Virtual Reality ...
# 4  This course provides a foundational understand...
#
#                                                 text
# 0  Network Security Information Technology Comput...
# 1  Security Principles Information Technology Cyb...
# 2  21st Century Energy Transition: how do we make...
# 3  VR and 360 Video Production Arts And Humanitie...
# 4  Foundations of Human Anatomy and Physiology He...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english', max_features=20000)
tfidf_matrix = tfidf.fit_transform(df['text'])
# Out:
# (5411, 20000)

# %%
#cosine similarity
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#index mapping
df['name_lower'] = df['name'].str.lower()
indices = pd.Series(df.index, index=df['name_lower']).drop_duplicates()

# %%
# function for course similarity
def recommend_similar_courses(course_name, n=10):
    course_name = course_name.lower()
    
    if course_name not in indices:
        print("Course not found. Please check the name.")
        return pd.DataFrame()
    
    idx = indices[course_name]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # skip the first one (same course)
    sim_scores = sim_scores[1:n+1]
    
    course_indices = [i[0] for i in sim_scores]
    
    return df[['name', 'category', 'skills', 'language',]].iloc[course_indices]

# %%
# testing
recommend_similar_courses("networksecurity", n=5)
# Out:
# Course not found. Please check the name.
# Empty DataFrame
# Columns: []
# Index: []
